# %%
import requests
import pdfplumber
from io import BytesIO
import openai
from openai import OpenAI
import json
import re
import pandas as pd
from dotenv import load_dotenv
import os
from llama_parse import LlamaParse
import nest_asyncio
nest_asyncio.apply()

# %%
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI()

# %%
# def extract_tables(pdf_path, api_key=None, use_ocr=True):
#     if not os.path.isfile(pdf_path):
#         raise FileNotFoundError(f"File not found: {pdf_path}")
    
#     parser = LlamaParse(
#         api_key="llx-HdgBKfPPO6vVO0CeuSkOduMH5DaCuLwuDsBHJsjMLS2Y6dod",
#         result_type="markdown",
#         extract_charts=True,
#         auto_mode=True,
#         auto_mode_trigger_on_image_in_page=True,
#         auto_mode_trigger_on_table_in_page=True,
#     )

#     docs = parser.load_data(pdf_path)
#     tables = []

#     for doc in docs:
#         if hasattr(doc, 'metadata') and 'tables' in doc.metadata:
#             tables = doc.metadata['tables']
#         else:
#             lines = doc.text.split('\n')
#             start_idxs, end_idxs = [], []
#             in_table, start = False, 0

#             for i, line in enumerate(lines):
#                 line = line.strip()
#                 if line.startswith('|') and '|' in line[1:]:
#                     if not in_table:
#                         in_table, start = True, i
#                 elif in_table and '---' in line and '|' in line:
#                     continue
#                 elif in_table and (not line.startswith('|') or line == ''):
#                     in_table = False
#                     start_idxs.append(start)
#                     end_idxs.append(i)

#             if in_table:
#                 start_idxs.append(start)
#                 end_idxs.append(len(lines))

#             for s, e in zip(start_idxs, end_idxs):
#                 content = '\n'.join(lines[s:e])
#                 tables.append({
#                     'content': content,
#                     'type': 'table',
#                     'page_number': None,
#                 })

#         if not tables and use_ocr and hasattr(doc, 'pages'):
#             for i, page in enumerate(doc.pages):
#                 text = page.text if hasattr(page, 'text') else ""
#                 if text.count('|') > 10:
#                     lines = text.split('\n')
#                     t_lines = []
#                     in_block = False

#                     for line in lines:
#                         if '|' in line and line.count('|') >= 3:
#                             if not in_block:
#                                 in_block = True
#                                 t_lines = [line]
#                             else:
#                                 t_lines.append(line)
#                         elif in_block and len(line.strip()) < 3:
#                             in_block = False
#                             if len(t_lines) >= 3:
#                                 tables.append({
#                                     'content': '\n'.join(t_lines),
#                                     'type': 'table',
#                                     'page_number': i + 1,
#                                     'extracted_via': 'heuristic'
#                                 })
#                             t_lines = []
#                         elif in_block:
#                             t_lines.append(line)

#                     if in_block and len(t_lines) >= 3:
#                         tables.append({
#                             'content': '\n'.join(t_lines),
#                             'type': 'table',
#                             'page_number': i + 1,
#                             'extracted_via': 'heuristic'
#                         })

#     return tables

# %%
# def extract_tables(pdf_path, api_key=None, use_ocr=True, context_chars=100):
#     if not os.path.isfile(pdf_path):
#         raise FileNotFoundError(f"File not found: {pdf_path}")

#     parser = LlamaParse(
#         api_key="llx-HdgBKfPPO6vVO0CeuSkOduMH5DaCuLwuDsBHJsjMLS2Y6dod",
#         result_type="markdown",
#         extract_charts=True,
#         auto_mode=True,
#         auto_mode_trigger_on_image_in_page=True,
#         auto_mode_trigger_on_table_in_page=True,
#     )

#     docs = parser.load_data(pdf_path)
#     tables = []

#     for doc in docs:
#         full_text = doc.text
#         lines = full_text.split('\n')

#         # Build char offsets to map line index to char position
#         char_offsets = [0]
#         for line in lines:
#             char_offsets.append(char_offsets[-1] + len(line) + 1)

#         start_idxs, end_idxs = [], []
#         in_table, start = False, 0

#         for i, line in enumerate(lines):
#             line = line.strip()
#             if line.startswith('|') and '|' in line[1:]:
#                 if not in_table:
#                     in_table, start = True, i
#             elif in_table and '---' in line and '|' in line:
#                 continue
#             elif in_table and (not line.startswith('|') or line == ''):
#                 in_table = False
#                 start_idxs.append(start)
#                 end_idxs.append(i)

#         if in_table:
#             start_idxs.append(start)
#             end_idxs.append(len(lines))

#         for s, e in zip(start_idxs, end_idxs):
#             table_text = '\n'.join(lines[s:e])
#             char_start = char_offsets[s]
#             char_end = char_offsets[e] if e < len(char_offsets) else len(full_text)

#             pre = full_text[max(0, char_start - context_chars):char_start].strip()

#             tables.append({
#                 'content': table_text,
#                 'type': 'table',
#                 'page_number': None,
#                 'context_before': pre,
#             })

#         if not tables and use_ocr and hasattr(doc, 'pages'):
#             for i, page in enumerate(doc.pages):
#                 text = page.text if hasattr(page, 'text') else ""
#                 if text.count('|') > 10:
#                     lines = text.split('\n')
#                     in_block = False
#                     block_lines = []

#                     for j, line in enumerate(lines):
#                         if '|' in line and line.count('|') >= 3:
#                             if not in_block:
#                                 in_block = True
#                                 block_lines = [line]
#                             else:
#                                 block_lines.append(line)
#                         elif in_block and len(line.strip()) < 3:
#                             in_block = False
#                             if len(block_lines) >= 3:
#                                 block_text = '\n'.join(block_lines)

#                                 # Get char positions for context
#                                 flat_text = '\n'.join(lines)
#                                 block_str = '\n'.join(block_lines)
#                                 block_idx = flat_text.find(block_str)
#                                 pre = flat_text[max(0, block_idx - context_chars):block_idx].strip()

#                                 tables.append({
#                                     'content': block_text,
#                                     'type': 'table',
#                                     'page_number': i + 1,
#                                     'context_before': pre,
#                                     'extracted_via': 'heuristic'
#                                 })
#                             block_lines = []
#                         elif in_block:
#                             block_lines.append(line)

#                     if in_block and len(block_lines) >= 3:
#                         block_text = '\n'.join(block_lines)
#                         flat_text = '\n'.join(lines)
#                         block_idx = flat_text.find(block_text)
#                         pre = flat_text[max(0, block_idx - context_chars):block_idx].strip()

#                         tables.append({
#                             'content': block_text,
#                             'type': 'table',
#                             'page_number': i + 1,
#                             'context_before': pre,
#                             'extracted_via': 'heuristic'
#                         })

#     return tables

# %%
enrollment_template_prompt = """
You are given tables extracted from a school's PDF disclosure document.

Your task is to extract enrollment-related data from these tables. The fields of interest include, but are not limited to, the following:

Fields marked as most important:
- Undergraduate Headcount
- Graduate Headcount
- Professional Headcount (Tip: combined the enrollement of the profession related school such as med school, law school, etc)
- Total Headcount
- Undergraduate FTE
- Graduate FTE
- Professional FTE
- Total Full-Time Equivalent Students
- Applications Rcvd
- Acceptances
- Matriculants
- Retention Rate %
- Full-Time Employee Equivalents
- Tuition
- Room & Board (20 meals)

IF the year is not included in the table, use the pre context to figure out the school year the table is responsible for.

DO NOT assume the year of the data. 

Extract data STRICTLY for the years 2019 through 2024, if available (although not all data going to be in that order).

Important:
**Do not assume** that the document’s publication or posting year is the same as the data year. Carefully read and extract the actual years provided in the tables themselves. For example, a document published in 2025 might contain data for the fiscal year ending in 2024.

### Output Format:
Return a JSON object where each key is a field name and each value is a dictionary of {year: value}, such as:

{
  "Undergraduate Headcount": {
    "2024": 4107,  
    "2023": 4100,
    "2022":
    ...
  },
  "Graduate Headcount": {
    "2024": 49800,
    "2023": 48000.
    "2022":
    ...
  }
}
The output format order HAS to follow the order of the fields I listed above at the "all the fields" part.

If a field is not found, omit it. I would prefer no data over faulty data. Return **only** the JSON.
"""

# %%
def data_extraction(tables, prompt, max_chars = 100000):
    # if any(isinstance(tbl, list) for tbl in tables):
    #     tables = [t for sublist in tables for t in sublist]
    
    # table_texts = [t['content'] for t in tables if isinstance(t, dict) and 'content' in t]
    combined_text = "\n\n".join([doc.text for doc in tables])
    input_prompt = f"{prompt}\n\n### Tables Extracted:\n\n{combined_text}"

    try:
        response = client.chat.completions.create(
            model="gpt-4-turbo",
            messages=[{"role": "user", "content": input_prompt}],
            temperature=0.2,
            max_tokens=2000
        )

        results = response.choices[0].message.content
    except Exception as e:
        print(f"Error extracting from {filename}: {e}")

    return results

# %%
def clean_output(raw_text):

    cleaned = re.sub(r"```json|```", "", raw_text).strip()

    # Remove inline comments: // anything after
    cleaned = re.sub(r'//.*', '', cleaned)

    # Optionally strip any trailing commas
    cleaned = re.sub(r',\s*}', '}', cleaned)
    cleaned = re.sub(r',\s*\]', ']', cleaned)

    return json.loads(cleaned)

# %%
documents_with_instruction = LlamaParse(
    api_key="llx-HdgBKfPPO6vVO0CeuSkOduMH5DaCuLwuDsBHJsjMLS2Y6dod",
    result_type="markdown",
    parsing_instruction="""
    This is the a school financial report. I would need you to extract information which are related to enrollment, headcount, FTE, admission, faculty, tuition and fees, student characteristics(Graduation rate, ACT, SAT scores etc.)
    tips: Sometimes Graduate could be written as GR or Grad or, some university has multiple graduate schools, such as school of business, college of liberal artsm or GR Non-degree. you should include these data as well.
    tips: Include the according year of the information, sometimes it's no inlucded in the table, so look around it.
    """
    ).load_data("pdfs/MT_ST_MARY/Mt St Mary's fall 24 continuing disclosure.pdf")
extracted_tables = [] 

for document in documents_with_instruction:
    text = document.text
    if re.search(r"It seems that the text provided is not", text):
        continue
    if re.search(r"does not contain", text):
        continue

    # Check if the document is relevant:
    if text.lstrip().startswith("Here is the extracted information") or re.search(r"^\d{4}\s+", text, re.MULTILINE):
        extracted_tables.append(document)
# Out:
# WARNING: parsing_instruction is deprecated. Use system_prompt, system_prompt_append or user_prompt instead.
# Started parsing the file under job_id db7603fd-728d-40fa-977b-ff0e9cb6eb4b
# ..

# %%
all_tables
# Out:
# [Document(id_='1a578495-25ee-454c-a16c-3d4884b347af', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the financial report:\n\n### Enrollment and Admissions Data (Year Ending June 30, 2023)\n\n#### Freshman\n- **Applications:** 5994\n- **Acceptances:** 5659\n- **Enrolled:** 734\n\n#### Transfer\n- **Applications:** 368\n- **Acceptances:** 328\n- **Enrolled:** 129\n\n#### Graduate\n- **Applications:** 1857\n- **Acceptances:** 775\n- **Enrolled:** 361\n\n### Enrollment and Degrees (All Campuses Fall 2023)\n\n#### Undergraduate\n- **Head Count:** 3379\n- **FTE (Full-Time Equivalent):** 3088\n- **Associates Degree:** 14\n- **Bachelor Degree:** 808\n\n#### Graduate\n- **Head Count:** 1731\n- **FTE:** 1167\n- **Master’s Degree:** 666\n\n#### Graduate Non-Degree Professional Development\n- **Head Count:** 1932\n- **FTE:** 935\n\n#### Law School\n- **Head Count:** 332\n- **FTE:** 193\n- **Law Degree (J.D.):** 47\n\n### Summary\n- **Total Enrollment (Undergraduate + Graduate + Law School):**\n- Undergraduate: 3379\n- Graduate: 1731\n- Graduate Non-Degree: 1932\n- Law School: 332\n\nThis information provides a comprehensive overview of the student applications, admissions, enrollment figures, and degrees offered for the specified year.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='7178ab51-ea33-4f91-9d6d-e2b4303124ee', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the financial report for the year ending June 30, 2023:\n\n### Enrollment and Headcount\n- **Doctoral Head Count**: 301\n- **Doctoral FTE (Full-Time Equivalent)**: 233\n- **Doctoral Degrees Awarded**: 49\n\n### Financial Aid (in 000’s)\n- **State Financial Aid**: $6,425\n- **Federal Financial Aid**: $4,419\n- **Student Funded Financial Aid**: $37,937\n- **Work Study Financial Aid**: $1,111\n- **Other Financial Aid**: $35,343\n- **Total Financial Aid**: $85,234\n\n### Financial Aid for 2022 (in 000’s)\n- **State Financial Aid**: $5,398\n- **Federal Financial Aid**: $4,012\n- **Student Funded Financial Aid**: $38,591\n- **Work Study Financial Aid**: $1,179\n- **Other Financial Aid**: $31,177\n- **Total Financial Aid**: $80,357\n\n### Tuition and Fees for 2023-24\n- **Undergraduate – Online Per Unit**: $665\n- **Undergraduate – Full Year**: $48,300\n- **Undergraduate – Part Time Per Unit**: $150\n- **Undergraduate – Study Abroad (Per Semester)**: $30,725\n- **Paralegal – Per Unit**: $500\n- **Room & Board – Full Year**: $15,750 (double occupancy, 19 meals)\n\n### Notations\n1. Packaged, not disbursed data for enrolled students.\n2. Student funded includes Federal Student Loans (Stafford, PLUS, Perkins), Non-Federal Loans, and ULV Loans.\n3. Other includes institutional scholarships and funds from non-University and non-Federal sources.\n\nThis information provides a comprehensive overview of the financial aspects related to enrollment, tuition, and financial aid for the specified year.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='0528f5a7-c1a2-4ee2-a51d-d87d36c0a9ed', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the financial report for the year ending June 30, 2023:\n\n### Enrollment and Degrees (Year 2022-2023)\n\n#### Undergraduate:\n- **Head Count:** 3,833\n- **FTE (Full-Time Equivalent):** 3,121\n- **Associates Degree:** 14\n- **Bachelor Degree:** 808\n\n#### Graduate:\n- **Head Count:** 2,215\n- **FTE:** 1,419\n- **Master’s Degree:** 666\n\n#### Graduate Non-Degree Professional Development:\n- **Head Count:** 8,186\n- **FTE:** 2,440\n\n#### Corrected 2022 Graduate Non-Degree Professional Development:\n- **Head Count:** 8,277\n- **FTE:** 2,443\n\n#### Law School:\n- **Head Count:** 323\n- **FTE:** 336\n- **Law Degree (J.D.):** 47\n\n#### Doctoral:\n- **Head Count:** 297\n- **FTE:** 208\n- **Doctoral Degree:** 49\n\n### Summary:\n- Total Enrollment (Undergraduate + Graduate + Law + Doctoral):\n- Undergraduate: 3,833\n- Graduate: 2,215\n- Graduate Non-Degree: 8,186\n- Law School: 323\n- Doctoral: 297\n\nThis report provides a comprehensive overview of the enrollment statistics for the University of La Verne for the academic year 2022-2023.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
pdf_folder = "pdfs/Mt St Mary's fall 24 continuing disclosure.pdf"

all_tables = extracted_tables

gpt_output = data_extraction(all_tables, enrollment_template_prompt)

try:
    results = clean_output(gpt_output)
except Exception as e:
    print("JSON parsing failed:", e)
    print("GPT Raw Output:\n", gpt_output)
    results = {}

with open("enrollment_data.json", "w") as f:
    json.dump(results, f, indent=2)

# %%
df1 = pd.DataFrame(results)
df1
# Out:
#       Undergraduate Headcount  Graduate Headcount  Total Headcount  \
# 2024                     1830                 579             2408
# 2023                     1873                 738             2499
# 2022                     1896                 724             2456
# 2021                     2055                 693             2570
# 2020                     2072                 717             2561
#
#       Total Full-Time Equivalent Students  Applications Rcvd  Acceptances  \
# 2024                                 2134               6041         4459
# 2023                                 2255               5437         3896
# 2022                                 2248               4346         3458
# 2021                                 2367               4620         3777
# 2020                                 2379               6442         5221
#
#       Matriculants  Retention Rate %  Tuition  Room & Board (20 meals)
# 2024           545                77    47240                     7950
# 2023           482                75    45870                     7630
# 2022           459                79    44750                     7435
# 2021           532                74    43650                     7230
# 2020           647                76    42590                     7020

# %%
pdf_folder = "pdfs/U La Verne CA fall 23 continuing disclosure.pdf"

all_tables = extracted_tables

gpt_output = data_extraction(all_tables, enrollment_template_prompt)

try:
    results = clean_output(gpt_output)
except Exception as e:
    print("JSON parsing failed:", e)
    print("GPT Raw Output:\n", gpt_output)
    results = {}

with open("enrollment_data.json", "w") as f:
    json.dump(results, f, indent=2)

# %%
df2 = pd.DataFrame(results)
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
extracted_tables
# Out:
# [Document(id_='fc259731-279e-4509-8368-22e846d09913', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the provided financial report:\n\n### Enrollment and Admissions:\n- **Freshman**\n- Applications: 5994\n- Acceptances: 5659\n- Enrolled: 734\n\n- **Transfer**\n- Applications: 368\n- Acceptances: 328\n- Enrolled: 129\n\n- **Graduate**\n- Applications: 1857\n- Acceptances: 775\n- Enrolled: 361\n\n### Enrollment and Degrees:\n- **Undergraduate**\n- Head Count: 3379\n- FTE (Full-Time Equivalent): 3088\n- Associates Degree: 14\n- Bachelor Degree: 808\n\n- **Graduate**\n- Head Count: 1731\n- FTE: 1167\n- Master’s Degree: 666\n\n- **Graduate Non-Degree Professional Development**\n- Head Count: 1932\n- FTE: 935\n\n- **Law School**\n- Head Count: 332\n- FTE: 193\n- Law Degree (J.D.): 47\n\n### Summary:\n- Total Undergraduate Enrollment (Head Count): 3379\n- Total Graduate Enrollment (Head Count): 1731\n- Total Graduate Non-Degree Enrollment (Head Count): 1932\n- Total Law School Enrollment (Head Count): 332\n\nThis report provides a comprehensive overview of student applications, admissions, and enrollment figures across various programs and degrees.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1d0a3bc5-0487-4385-bef4-7bea4267f80b', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the provided financial report:\n\n### Enrollment and Headcount\n- **Doctoral Head Count**: 301\n- **Doctoral FTE (Full-Time Equivalent)**: 233\n- **Doctoral Degrees Awarded**: 49\n\n### Financial Aid\n- **Total Financial Aid (2023)**: $85,234,000\n- **State Aid**: $6,425,000\n- **Federal Aid**: $4,419,000\n- **Student Funded**: $37,937,000\n- **Work Study**: $1,111,000\n- **Other**: $35,343,000\n\n### Tuition and Fees (2023-24)\n- **Undergraduate Tuition Fees**:\n- **Online Per Unit**: $665\n- **Full Year (Traditional)**: $48,300\n- **Part Time Per Unit**: $1,365\n- **Study Abroad (Per Semester)**: $30,725\n- **Paralegal Per Unit**: $500\n- **Room & Board (Full Year)**: $15,750 (double occupancy, 19 meals)\n\n### Notations\n- Packaged, not disbursed data for enrolled students.\n- Student funded includes Federal Student Loans (Stafford, PLUS, Perkins), Non-Federal Loans, and ULV Loans.\n- Other includes institutional scholarships and funds from non-University and non-Federal sources.\n\n### Previous Year Financial Aid (2022)\n- **Total Financial Aid (2022)**: $80,357,000\n- **State Aid**: $5,398,000\n- **Federal Aid**: $4,012,000\n- **Student Funded**: $38,591,000\n- **Work Study**: $1,179,000\n- **Other**: $31,177,000\n\n### Student Characteristics\n- No specific data on graduation rates, ACT, or SAT scores was provided in the text.\n\nThis summary captures the key financial and enrollment-related data from the report. If you need further details or additional information, please let me know!', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='0302458b-ac42-4a32-8da7-1c3b1abc7e8a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the provided financial report:\n\n### Enrollment and Headcount\n- **Graduate Programs**:\n- Graduate-Masters per Unit: 740-935\n- Graduate Doctoral per Unit: 1,235-1,275\n- Law-Per Year (ABA Cont. Full-Time): 15,140\n- Law-Per Year (New Full Time): 1,400\n- Law-Per Year (ABA Cont. Part-Time): 12,975\n- Law-Per Year (New Part-Time): 1,075\n\n### Tuition and Fees\n- **Graduate Tuition**:\n- Graduate-Masters per Unit: 740-935\n- Graduate Doctoral per Unit: 1,235-1,275\n- **Law Tuition**:\n- Law-Per Unit Continuing (Cal Bar): 1,075\n- Law-Per Year (ABA Cont. Full-Time): 15,140\n- Law-Per Year (New Full Time): 1,400\n- Law-Per Year (ABA Cont. Part-Time): 12,975\n- Law-Per Year (New Part-Time): 1,075\n- **Regional Online Campus Administration (ROC)**:\n- ROC - CAPA: 665\n- ROC - California RC (Undergraduate, Military): 250\n- ROC - California RC (Graduate, Military): 385\n- ROC - California PDC (Undergraduate): 665\n- ROC - California PDC (Graduate/MBA): 935\n- ROC - California PDC (Graduate/MHA): 785\n- ROC - California PDC (Graduate/Education): 740\n- ROC - Non-Degree Professional Development Courses: 135 per Semester hour\n\n### Student Characteristics\n- No specific data on graduation rates, ACT, or SAT scores were provided in the text.\n\n### Additional Notes\n- The report includes various graduate programs, indicating a diverse range of offerings, including Masters, Doctoral, and Law programs.\n- The tuition rates vary significantly based on the program and whether the student is full-time or part-time.\n\nIf you need further details or specific data points, please let me know!', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='35520972-e37c-46b8-8436-75f3300a7a34', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Here is the extracted information related to enrollment, headcount, FTE, admission, faculty, tuition and fees, and student characteristics from the provided financial report:\n\n### Enrollment and Degrees\n\n#### Undergraduate\n- **Head Count**: 3,833\n- **FTE (Full-Time Equivalent)**: 3,121\n- **Associates Degree**: 14\n- **Bachelor Degree**: 808\n\n#### Graduate\n- **Head Count**: 2,215\n- **FTE**: 1,419\n- **Master’s Degree**: 666\n\n#### Graduate Non-Degree Professional Development\n- **Head Count**: 8,186\n- **FTE**: 2,440\n- **Corrected 2022 Graduate Non-Degree Professional Development**\n- **Head Count**: 8,277\n- **FTE**: 2,443\n\n#### Law School\n- **Head Count**: 323\n- **FTE**: 336\n- **Law Degree (J.D.)**: 47\n\n#### Doctoral\n- **Head Count**: 297\n- **FTE**: 208\n- **Doctoral Degree**: 49\n\n### Summary\n- Total Enrollment (Undergraduate + Graduate + Law + Doctoral):\n- Undergraduate: 3,833\n- Graduate: 2,215\n- Graduate Non-Degree: 8,186\n- Law School: 323\n- Doctoral: 297\n\nThis report provides a comprehensive overview of the enrollment figures, including headcount and FTE for various degree programs.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]
